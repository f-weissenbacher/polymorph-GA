# %%
import os
from os.path import join
import matplotlib.pyplot as plt
from Utilities import deleteTempfiles
from GeneticAlgorithm import GeneticAlgorithm
from Polymorph import Polymorph
from PolymorphFactory import PolymorphFactory
from Mutators import FullRangeMutator, IncrementalMutator, MultiplicativeMutator

molecules_dir = os.path.abspath("../molecules")
testing_dir = os.path.abspath("../testing")
structure_filepath = join(molecules_dir, "molecule4.xyz")

os.chdir(testing_dir)

# %%
mutation_rate = 0.05
crossover_rate = 0.01

#bond_mutator = MultiplicativeMutator('bond',[0.8,1.2],[0.8,1.2], False, mutation_rate)

#bond_mutator = None
#angle_mutator = IncrementalMutator('angle', )

factory = PolymorphFactory(structure_filepath, mutation_rate, crossover_rate)
# Out:
# Running DFT calculation for base polymorph
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7684.6 eV
# Dipole moment(X, Y, Z, Debye):  1.26105,  1.48208, -0.90559

# %%
factory.freezeBonds('all')
#factory.freezeAngles('all')
#factory.freezeDihedrals('all-improper')

# %%
ga = GeneticAlgorithm(factory, generation_size=15, discard_mode='least-fittest',
                      fitness_property=Polymorph.DIPOLE_MOMENT, fitness_goal='maximize',
                      matchmaking_mode='roulette')
# Out:
# Spawning initial generation ...
# Setup of genetic algorithm complete.

# %%
ga.renderGeneration()

# %%
ga.doMultipleGenerationSteps(30, verbose=False)
# Out:
# #------------------------------------------------------------
# #  Generation 0
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 0) ...
# Polymorph 1 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7657.5 eV
# Dipole moment(X, Y, Z, Debye): -0.65374, -1.46243,  0.54806
# Polymorph 2 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7625.1 eV
# Dipole moment(X, Y, Z, Debye):  3.10147, -4.25775, -1.09679
# Polymorph 3 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7640.46 eV
# Dipole moment(X, Y, Z, Debye):  2.77540, -2.34231, -1.09902
# Polymorph 4 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7648.44 eV
# Dipole moment(X, Y, Z, Debye):  2.73912,  1.42312, -4.37827
# Polymorph 5 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7649.5 eV
# Dipole moment(X, Y, Z, Debye): -0.73217,  0.39078, -1.79841
# Polymorph 6 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7631.18 eV
# Dipole moment(X, Y, Z, Debye):  2.88393, -4.53664, -0.71314
# Polymorph 7 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.46 eV
# Dipole moment(X, Y, Z, Debye):  3.33358,  2.54922, -2.24151
# Polymorph 8 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7626.11 eV
# Dipole moment(X, Y, Z, Debye): -2.07167,  5.40458, -0.47405
# Polymorph 9 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7653.67 eV
# Dipole moment(X, Y, Z, Debye):  1.47658,  1.20076,  3.39379
# Polymorph 10 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.48 eV
# Dipole moment(X, Y, Z, Debye):  0.62022,  1.77076,  2.50828
# Polymorph 11 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.31 eV
# Dipole moment(X, Y, Z, Debye):  0.99493,  0.59306, -2.54406
# Polymorph 12 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.06 eV
# Dipole moment(X, Y, Z, Debye): -2.24868,  5.26210,  2.57562
# Polymorph 13 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.79 eV
# Dipole moment(X, Y, Z, Debye):  2.92769, -1.41731,  1.78560
# Polymorph 14 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7625.13 eV
# Dipole moment(X, Y, Z, Debye):  1.54580, -0.20768, -2.67078
# Polymorph 15 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7628.5 eV
# Dipole moment(X, Y, Z, Debye): -0.19110,  0.87605,  1.08746
# Adding generation 0 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 1)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 1
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 1) ...
# Polymorph 6 unchanged
# Polymorph 8 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# Polymorph 8: Hartree-Fock calculation did not converge!
# Polymorph 12 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7650.98 eV
# Dipole moment(X, Y, Z, Debye): -2.67194,  4.07864,  2.07840
# Polymorph 16 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.96 eV
# Dipole moment(X, Y, Z, Debye): -1.22263,  1.06782,  0.80036
# Polymorph 17 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.87 eV
# Dipole moment(X, Y, Z, Debye):  2.01845,  4.70899,  3.09974
# Polymorph 18 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.26 eV
# Dipole moment(X, Y, Z, Debye):  3.57426,  2.07063, -2.66156
# Polymorph 19 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.22 eV
# Dipole moment(X, Y, Z, Debye):  1.34344,  1.67677,  2.66359
# Polymorph 20 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7613.42 eV
# Dipole moment(X, Y, Z, Debye):  7.53902, -1.78690, -0.23466
# Polymorph 21 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.07 eV
# Dipole moment(X, Y, Z, Debye):  3.29995, -1.01289, -2.41585
# Polymorph 22 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7627.02 eV
# Dipole moment(X, Y, Z, Debye):  2.71082,  4.05840, -2.37313
# Polymorph 23 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7647.16 eV
# Dipole moment(X, Y, Z, Debye):  2.11378, -0.35141,  0.85389
# Polymorph 24 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.62 eV
# Dipole moment(X, Y, Z, Debye):  4.30120, -0.51509,  0.59311
# Polymorph 25 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7621 eV
# Dipole moment(X, Y, Z, Debye):  3.07882,  3.65924, -6.20925
# Polymorph 26 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7624.2 eV
# Dipole moment(X, Y, Z, Debye):  2.35016,  4.30389, -1.14850
# Polymorph 27 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.48 eV
# Dipole moment(X, Y, Z, Debye):  5.11380, -0.29973, -0.37688
# Adding generation 1 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 2)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 2
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 2) ...
# Polymorph 17 unchanged
# Polymorph 20 unchanged
# Polymorph 25 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7619.16 eV
# Dipole moment(X, Y, Z, Debye):  3.08112,  3.16232, -5.13507
# Polymorph 28 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7629.49 eV
# Dipole moment(X, Y, Z, Debye):  3.00698, -3.34240,  1.73379
# Polymorph 29 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.9 eV
# Dipole moment(X, Y, Z, Debye):  4.28604, -1.36166,  1.75611
# Polymorph 30 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7655.14 eV
# Dipole moment(X, Y, Z, Debye):  2.92388, -1.32931,  0.93572
# Polymorph 31 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7607.89 eV
# Dipole moment(X, Y, Z, Debye):  1.22613,  3.47281, -0.54823
# Polymorph 32 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7644.22 eV
# Dipole moment(X, Y, Z, Debye):  3.68892,  0.05328, -3.44663
# Polymorph 33 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7631.52 eV
# Dipole moment(X, Y, Z, Debye): -1.00747, -2.17002,  0.37650
# Polymorph 34 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.03 eV
# Dipole moment(X, Y, Z, Debye):  3.25217, -4.43737, -0.25383
# Polymorph 35 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7653.58 eV
# Dipole moment(X, Y, Z, Debye):  1.66070,  2.27913,  1.77552
# Polymorph 36 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7619.35 eV
# Dipole moment(X, Y, Z, Debye): -1.38586,  4.05368,  2.48372
# Polymorph 37 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.65 eV
# Dipole moment(X, Y, Z, Debye):  3.71811, -2.89261, -2.75142
# Polymorph 38 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7620.72 eV
# Dipole moment(X, Y, Z, Debye):  1.20323,  3.49796, -0.15552
# Polymorph 39 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7646.2 eV
# Dipole moment(X, Y, Z, Debye):  3.62357, -1.91497,  1.72934
# Adding generation 2 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 3)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 3
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 3) ...
# Polymorph 17 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.85 eV
# Dipole moment(X, Y, Z, Debye):  2.25948,  4.52050,  2.80178
# Polymorph 20 unchanged
# Polymorph 25 unchanged
# Polymorph 40 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.49 eV
# Dipole moment(X, Y, Z, Debye):  5.01525, -2.69077,  0.40058
# Polymorph 41 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7653.95 eV
# Dipole moment(X, Y, Z, Debye):  2.74131,  0.85374, -0.76210
# Polymorph 42 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7647.47 eV
# Dipole moment(X, Y, Z, Debye):  4.25608,  0.76442, -0.58046
# Polymorph 43 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7655.74 eV
# Dipole moment(X, Y, Z, Debye):  1.43042,  0.94604,  0.82586
# Polymorph 44 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7627.7 eV
# Dipole moment(X, Y, Z, Debye):  2.47668,  4.20979, -1.00744
# Polymorph 45 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.84 eV
# Dipole moment(X, Y, Z, Debye):  0.38667,  5.66485,  2.71543
# Polymorph 46 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7628.71 eV
# Dipole moment(X, Y, Z, Debye):  1.78060,  1.51021, -1.85146
# Polymorph 47 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7626.7 eV
# Dipole moment(X, Y, Z, Debye): -3.09527,  2.23153, -2.40873
# Polymorph 48 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7646.97 eV
# Dipole moment(X, Y, Z, Debye):  0.71668, -5.15718,  1.43391
# Polymorph 49 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7619.56 eV
# Dipole moment(X, Y, Z, Debye):  3.34936, -1.27341, -1.17210
# Polymorph 50 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7649.5 eV
# Dipole moment(X, Y, Z, Debye): -1.34296,  0.98560, -3.76363
# Polymorph 51 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7627.49 eV
# Dipole moment(X, Y, Z, Debye):  3.90625,  2.84861, -0.37793
# Adding generation 3 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 4)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 4
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 4) ...
# Polymorph 20 unchanged
# Polymorph 25 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7618.15 eV
# Dipole moment(X, Y, Z, Debye):  3.34160,  2.96858, -5.29261
# Polymorph 45 unchanged
# Polymorph 52 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.76 eV
# Dipole moment(X, Y, Z, Debye):  2.90947,  2.45804,  4.24470
# Polymorph 53 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7629.33 eV
# Dipole moment(X, Y, Z, Debye):  1.16425,  4.04030, -2.28355
# Polymorph 54 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7646.38 eV
# Dipole moment(X, Y, Z, Debye):  6.92661, -1.21466,  0.30557
# Polymorph 55 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.14 eV
# Dipole moment(X, Y, Z, Debye):  3.65450,  1.08483,  0.66615
# Polymorph 56 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7647.1 eV
# Dipole moment(X, Y, Z, Debye):  0.28327,  1.56216, -2.24410
# Polymorph 57 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.22 eV
# Dipole moment(X, Y, Z, Debye):  5.21254,  0.10075,  1.10368
# Polymorph 58 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.26 eV
# Dipole moment(X, Y, Z, Debye):  5.45504, -1.11027, -1.72961
# Polymorph 59 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7615.38 eV
# Dipole moment(X, Y, Z, Debye):  0.66456,  2.17502,  2.70271
# Polymorph 60 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7610.28 eV
# Dipole moment(X, Y, Z, Debye): -0.06703,  4.84921, -2.65278
# Polymorph 61 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7630.26 eV
# Dipole moment(X, Y, Z, Debye):  1.48558, -1.30378, -1.41127
# Polymorph 62 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7652.27 eV
# Dipole moment(X, Y, Z, Debye):  3.02355, -1.31767, -0.97171
# Polymorph 63 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7655.23 eV
# Dipole moment(X, Y, Z, Debye):  1.57633,  0.10575, -2.59170
# Adding generation 4 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 5)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 5
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 5) ...
# Polymorph 20 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7613.2 eV
# Dipole moment(X, Y, Z, Debye):  7.80520, -1.97025,  0.09447
# Polymorph 25 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7618.64 eV
# Dipole moment(X, Y, Z, Debye):  2.89354,  2.88171, -5.16880
# Polymorph 54 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.1 eV
# Dipole moment(X, Y, Z, Debye):  6.83303, -2.08132,  0.22835
# Polymorph 64 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.42 eV
# Dipole moment(X, Y, Z, Debye):  6.07065,  4.61683, -0.17618
# Polymorph 65 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7629.35 eV
# Dipole moment(X, Y, Z, Debye):  1.94644,  0.15029,  1.20906
# Polymorph 66 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7648.17 eV
# Dipole moment(X, Y, Z, Debye):  4.41437, -1.88255, -0.66102
# Polymorph 67 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7644.49 eV
# Dipole moment(X, Y, Z, Debye):  1.47120, -3.30916,  0.33432
# Polymorph 68 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7657.27 eV
# Dipole moment(X, Y, Z, Debye): -1.22837,  0.25174,  0.67683
# Polymorph 69 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.46 eV
# Dipole moment(X, Y, Z, Debye): -2.71492,  0.36652,  0.69205
# Polymorph 70 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7628.75 eV
# Dipole moment(X, Y, Z, Debye):  1.07168,  4.71464, -4.67815
# Polymorph 71 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7632.02 eV
# Dipole moment(X, Y, Z, Debye): -2.26028, -0.24385, -1.56846
# Polymorph 72 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7652.71 eV
# Dipole moment(X, Y, Z, Debye):  4.02936,  0.77739, -3.01602
# Polymorph 73 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7616.51 eV
# Dipole moment(X, Y, Z, Debye): -2.19778,  2.09443, -1.64934
# Polymorph 74 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.97 eV
# Dipole moment(X, Y, Z, Debye):  0.87319,  3.45203, -4.81706
# Polymorph 75 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7632.14 eV
# Dipole moment(X, Y, Z, Debye):  3.28494, -1.10620,  0.46341
# Adding generation 5 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 6)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 6
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 6) ...
# Polymorph 20 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7613.23 eV
# Dipole moment(X, Y, Z, Debye):  7.73843, -1.95575,  0.08249
# Polymorph 54 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.53 eV
# Dipole moment(X, Y, Z, Debye):  7.95516, -2.39933,  0.03251
# Polymorph 64 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.05 eV
# Dipole moment(X, Y, Z, Debye):  6.16028,  4.12600,  0.10870
# Polymorph 76 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7640.14 eV
# Dipole moment(X, Y, Z, Debye):  2.42865,  2.73812, -1.35689
# Polymorph 77 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7649.95 eV
# Dipole moment(X, Y, Z, Debye):  0.62135,  0.86677, -1.78551
# Polymorph 78 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.73 eV
# Dipole moment(X, Y, Z, Debye): -2.01265,  2.56941, -0.40388
# Polymorph 79 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7621.44 eV
# Dipole moment(X, Y, Z, Debye):  1.38500,  1.74765, -2.22446
# Polymorph 80 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.54 eV
# Dipole moment(X, Y, Z, Debye):  5.77112, -0.74958, -1.07887
# Polymorph 81 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.73 eV
# Dipole moment(X, Y, Z, Debye): -1.52617,  0.74174, -3.05801
# Polymorph 82 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.47 eV
# Dipole moment(X, Y, Z, Debye):  3.44663, -3.51625, -1.93539
# Polymorph 83 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7606.11 eV
# Dipole moment(X, Y, Z, Debye):  1.13597,  2.24130,  2.14682
# Polymorph 84 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7652.17 eV
# Dipole moment(X, Y, Z, Debye):  4.70989, -0.50910, -0.01670
# Polymorph 85 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7622.8 eV
# Dipole moment(X, Y, Z, Debye): -1.32794,  2.36750, -1.59883
# Polymorph 86 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.67 eV
# Dipole moment(X, Y, Z, Debye):  1.55789,  1.43937, -5.14504
# Polymorph 87 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7617.81 eV
# Dipole moment(X, Y, Z, Debye):  0.84697,  1.91420, -6.66510
# Adding generation 6 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 7)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 7
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# /home/fawi/miniconda3/envs/polymorph-ga/lib/python3.7/site-packages/chemcoord/internal_coordinates/_zmat_class_core.py:537: UserWarning: For the dihedral reference of atom 11 the dummy atom 15 was inserted
#   warnings.warn(give_message(i=i, dummy_d=dummy_d), UserWarning)
# /home/fawi/miniconda3/envs/polymorph-ga/lib/python3.7/site-packages/chemcoord/internal_coordinates/_zmat_class_core.py:537: UserWarning: For the dihedral reference of atom 12 the dummy atom 16 was inserted
#   warnings.warn(give_message(i=i, dummy_d=dummy_d), UserWarning)
# Attempting gene crossovers ...
# Evaluating current generation (# 7) ...
# Polymorph 20 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7613.09 eV
# Dipole moment(X, Y, Z, Debye):  4.67553, -1.90618, -2.42032
# Polymorph 54 unchanged
# Polymorph 64 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.05 eV
# Dipole moment(X, Y, Z, Debye):  6.16028,  4.12600,  0.10870
# Polymorph 88 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.64 eV
# Dipole moment(X, Y, Z, Debye):  0.17020,  2.47930, -0.68687
# Polymorph 89 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7628.04 eV
# Dipole moment(X, Y, Z, Debye):  4.45185,  2.43941, -2.90424
# Polymorph 90 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.37 eV
# Dipole moment(X, Y, Z, Debye):  0.39493,  4.79647, -1.49665
# Polymorph 91 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.23 eV
# Dipole moment(X, Y, Z, Debye): -0.41623,  0.45809, -0.45048
# Polymorph 92 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7631.67 eV
# Dipole moment(X, Y, Z, Debye):  2.65934, -2.49235,  0.03116
# Polymorph 93 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.78 eV
# Dipole moment(X, Y, Z, Debye):  0.04881, -0.72675, -0.42928
# Polymorph 94 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.7 eV
# Dipole moment(X, Y, Z, Debye):  9.25719, -1.14042,  0.93570
# Polymorph 95 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.1 eV
# Dipole moment(X, Y, Z, Debye):  0.83860,  0.47589, -2.39958
# Polymorph 96 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.06 eV
# Dipole moment(X, Y, Z, Debye): -3.39637, -0.25717, -0.70486
# Polymorph 97 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7614.61 eV
# Dipole moment(X, Y, Z, Debye):  1.84849,  4.10481, -1.81437
# Polymorph 98 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.12 eV
# Dipole moment(X, Y, Z, Debye):  4.51121, -1.24824, -2.22412
# Polymorph 99 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.02 eV
# Dipole moment(X, Y, Z, Debye):  2.95304,  3.96591, -3.98368
# Adding generation 7 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 8)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 8
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 8) ...
# Polymorph 54 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.75 eV
# Dipole moment(X, Y, Z, Debye):  6.68268, -2.78691,  0.25948
# Polymorph 64 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.68 eV
# Dipole moment(X, Y, Z, Debye):  2.54252,  1.43598, -0.16474
# Polymorph 94 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.68 eV
# Dipole moment(X, Y, Z, Debye):  9.23813, -1.17232,  0.94488
# Polymorph 100 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.07 eV
# Dipole moment(X, Y, Z, Debye): -3.44723,  0.29195, -1.00814
# Polymorph 101 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.17 eV
# Dipole moment(X, Y, Z, Debye):  4.29253,  3.85288, -2.12405
# Polymorph 102 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7645.14 eV
# Dipole moment(X, Y, Z, Debye):  0.19104,  0.80449, -0.76313
# Polymorph 103 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.74 eV
# Dipole moment(X, Y, Z, Debye):  6.15652, -1.36412,  0.70750
# Polymorph 104 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7657.99 eV
# Dipole moment(X, Y, Z, Debye):  0.03314, -1.17630, -3.39470
# Polymorph 105 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7620.86 eV
# Dipole moment(X, Y, Z, Debye):  2.80640,  1.24018, -3.02244
# Polymorph 106 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7644.04 eV
# Dipole moment(X, Y, Z, Debye): -4.04470, -0.72378, -2.58394
# Polymorph 107 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7623.73 eV
# Dipole moment(X, Y, Z, Debye):  2.81567,  0.81355, -1.06290
# Polymorph 108 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7645.58 eV
# Dipole moment(X, Y, Z, Debye): -1.22642,  2.12245, -0.00483
# Polymorph 109 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7628.1 eV
# Dipole moment(X, Y, Z, Debye):  4.63325, -0.96221, -1.04319
# Polymorph 110 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.46 eV
# Dipole moment(X, Y, Z, Debye): -0.10913, -1.70287, -1.37869
# Polymorph 111 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7652.09 eV
# Dipole moment(X, Y, Z, Debye):  1.19951, -0.78162, -1.32301
# Adding generation 8 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 9)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 9
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 9) ...
# Polymorph 54 unchanged
# Polymorph 94 unchanged
# Polymorph 103 unchanged
# Polymorph 112 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.36 eV
# Dipole moment(X, Y, Z, Debye):  5.94947, -2.93484, -0.11719
# Polymorph 113 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7647.94 eV
# Dipole moment(X, Y, Z, Debye): -0.44113,  2.00646, -5.24796
# Polymorph 114 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.55 eV
# Dipole moment(X, Y, Z, Debye):  4.39653, -1.87001, -2.92024
# Polymorph 115 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7648.15 eV
# Dipole moment(X, Y, Z, Debye):  2.95051,  0.60094, -0.65189
# Polymorph 116 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.48 eV
# Dipole moment(X, Y, Z, Debye):  5.78154, -3.65145, -0.94289
# Polymorph 117 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.81 eV
# Dipole moment(X, Y, Z, Debye):  1.52879, -0.90584, -1.05273
# Polymorph 118 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7644.38 eV
# Dipole moment(X, Y, Z, Debye): -1.06487, -0.67648, -0.38545
# Polymorph 119 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7645.49 eV
# Dipole moment(X, Y, Z, Debye):  0.13333, -0.73933, -0.21893
# Polymorph 120 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7630.34 eV
# Dipole moment(X, Y, Z, Debye):  2.65968,  0.63629, -1.19631
# Polymorph 121 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.39 eV
# Dipole moment(X, Y, Z, Debye):  0.77665,  2.14499, -1.67253
# Polymorph 122 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7657.4 eV
# Dipole moment(X, Y, Z, Debye): -1.00616, -0.07211,  0.63956
# Polymorph 123 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7605.38 eV
# Dipole moment(X, Y, Z, Debye):  2.61377, -0.07332, -3.59556
# Adding generation 9 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 10)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 10
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 10) ...
# Polymorph 54 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.29 eV
# Dipole moment(X, Y, Z, Debye):  4.94347, -1.73452,  1.26243
# Polymorph 94 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.71 eV
# Dipole moment(X, Y, Z, Debye):  9.28346, -1.09573,  0.93116
# Polymorph 116 unchanged
# Polymorph 124 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.63 eV
# Dipole moment(X, Y, Z, Debye):  0.90120, -0.57539, -4.96308
# Polymorph 125 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.97 eV
# Dipole moment(X, Y, Z, Debye): -0.31083, -2.73143,  1.59154
# Polymorph 126 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7631.59 eV
# Dipole moment(X, Y, Z, Debye): -2.29224, -1.07111, -1.66972
# Polymorph 127 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.57 eV
# Dipole moment(X, Y, Z, Debye):  8.00617, -0.73940, -0.56252
# Polymorph 128 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.83 eV
# Dipole moment(X, Y, Z, Debye):  4.83148, -0.05702, -0.86526
# Polymorph 129 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.76 eV
# Dipole moment(X, Y, Z, Debye):  3.46823, -1.53485,  0.84031
# Polymorph 130 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7621.52 eV
# Dipole moment(X, Y, Z, Debye):  7.15546, -1.91677, -0.45058
# Polymorph 131 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7627.47 eV
# Dipole moment(X, Y, Z, Debye):  4.16923, -3.59714,  0.70558
# Polymorph 132 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.35 eV
# Dipole moment(X, Y, Z, Debye):  4.23686,  0.82493, -1.01342
# Polymorph 133 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7649.18 eV
# Dipole moment(X, Y, Z, Debye):  2.57197,  1.40139, -0.32845
# Polymorph 134 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7649.13 eV
# Dipole moment(X, Y, Z, Debye):  2.36068, -1.44489, -1.08531
# Polymorph 135 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.19 eV
# Dipole moment(X, Y, Z, Debye): -0.19492, -0.70458, -1.61440
# Adding generation 10 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 11)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 11
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 11) ...
# Polymorph 94 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.02 eV
# Dipole moment(X, Y, Z, Debye):  9.04126, -1.27948,  0.48368
# Polymorph 127 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.61 eV
# Dipole moment(X, Y, Z, Debye):  7.40610, -1.10817, -0.97162
# Polymorph 130 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7621.53 eV
# Dipole moment(X, Y, Z, Debye):  7.09483, -1.98501, -0.98500
# Polymorph 136 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7618.4 eV
# Dipole moment(X, Y, Z, Debye):  7.32952, -3.32931, -0.54295
# Polymorph 137 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.55 eV
# Dipole moment(X, Y, Z, Debye):  4.94540,  1.50840,  0.68492
# Polymorph 138 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.66 eV
# Dipole moment(X, Y, Z, Debye):  0.65539, -4.66859,  1.50410
# Polymorph 139 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7651.36 eV
# Dipole moment(X, Y, Z, Debye):  3.20077,  3.36102, -0.91566
# Polymorph 140 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7632.57 eV
# Dipole moment(X, Y, Z, Debye):  2.58388,  1.41484, -2.09484
# Polymorph 141 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7630.35 eV
# Dipole moment(X, Y, Z, Debye):  8.72983, -1.84374,  1.33709
# Polymorph 142 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7632.25 eV
# Dipole moment(X, Y, Z, Debye):  0.97598, -2.56545,  0.02341
# Polymorph 143 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7598.85 eV
# Dipole moment(X, Y, Z, Debye):  3.08842,  1.27324, -6.34609
# Polymorph 144 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.02 eV
# Dipole moment(X, Y, Z, Debye):  7.87907,  0.28311, -1.46921
# Polymorph 145 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7621.99 eV
# Dipole moment(X, Y, Z, Debye):  6.69614, -3.21037,  0.28343
# Polymorph 146 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.78 eV
# Dipole moment(X, Y, Z, Debye):  0.69285, -3.82327, -1.20239
# Polymorph 147 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7611.37 eV
# Dipole moment(X, Y, Z, Debye):  4.12659, -3.50270,  0.66540
# Adding generation 11 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 12)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 12
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 12) ...
# Polymorph 94 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.96 eV
# Dipole moment(X, Y, Z, Debye):  9.32727, -1.41498,  1.03348
# Polymorph 136 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7618.02 eV
# Dipole moment(X, Y, Z, Debye):  6.49068, -3.24677,  1.10182
# Polymorph 141 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7630.17 eV
# Dipole moment(X, Y, Z, Debye):  9.05376, -2.19481,  1.37205
# Polymorph 148 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7627.12 eV
# Dipole moment(X, Y, Z, Debye):  3.24529,  0.75982,  0.84773
# Polymorph 149 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7649.67 eV
# Dipole moment(X, Y, Z, Debye):  4.55302, -2.83982, -0.55983
# Polymorph 150 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7629.49 eV
# Dipole moment(X, Y, Z, Debye):  4.91372,  1.73582, -0.46165
# Polymorph 151 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7631.24 eV
# Dipole moment(X, Y, Z, Debye):  4.35203, -1.07681, -1.16669
# Polymorph 152 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.99 eV
# Dipole moment(X, Y, Z, Debye):  1.63091,  2.68393, -2.24641
# Polymorph 153 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7607.73 eV
# Dipole moment(X, Y, Z, Debye):  5.68134, -1.83159,  0.73955
# Polymorph 154 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7646.41 eV
# Dipole moment(X, Y, Z, Debye):  3.55769,  3.65305, -1.81933
# Polymorph 155 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7645.23 eV
# Dipole moment(X, Y, Z, Debye):  7.16486, -1.03952, -1.19360
# Polymorph 156 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7660.28 eV
# Dipole moment(X, Y, Z, Debye):  4.07886, -1.48903, -0.79378
# Polymorph 157 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.17 eV
# Dipole moment(X, Y, Z, Debye):  4.67569, -0.19080, -0.83990
# Polymorph 158 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7646.87 eV
# Dipole moment(X, Y, Z, Debye):  1.22601, -2.26678, -1.53812
# Polymorph 159 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.28 eV
# Dipole moment(X, Y, Z, Debye):  4.98722,  1.00087, -1.37726
# Adding generation 12 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 13)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 13
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 13) ...
# Polymorph 94 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.18 eV
# Dipole moment(X, Y, Z, Debye):  9.71562, -1.47120,  1.22403
# Polymorph 136 unchanged
# Polymorph 141 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7629.46 eV
# Dipole moment(X, Y, Z, Debye):  9.13608, -2.12967,  1.50425
# Polymorph 160 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7660.35 eV
# Dipole moment(X, Y, Z, Debye):  4.52996, -0.85147, -0.55267
# Polymorph 161 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.97 eV
# Dipole moment(X, Y, Z, Debye):  7.91181,  0.76202, -1.48622
# Polymorph 162 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7629.71 eV
# Dipole moment(X, Y, Z, Debye):  1.95077, -2.28815,  0.74593
# Polymorph 163 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7625.26 eV
# Dipole moment(X, Y, Z, Debye):  5.34146, -0.98251,  2.09578
# Polymorph 164 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.96 eV
# Dipole moment(X, Y, Z, Debye): 11.34509, -2.25122,  0.31762
# Polymorph 165 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7640.57 eV
# Dipole moment(X, Y, Z, Debye):  9.55487, -2.30179, -0.44490
# Polymorph 166 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.18 eV
# Dipole moment(X, Y, Z, Debye):  5.02859, -0.04347,  0.00001
# Polymorph 167 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7617.54 eV
# Dipole moment(X, Y, Z, Debye):  4.46003, -2.00620,  1.02091
# Polymorph 168 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7654.71 eV
# Dipole moment(X, Y, Z, Debye):  1.93489, -0.79780, -1.75809
# Polymorph 169 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7655.16 eV
# Dipole moment(X, Y, Z, Debye):  4.80850,  0.05840, -1.25379
# Polymorph 170 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.93 eV
# Dipole moment(X, Y, Z, Debye):  6.71118, -3.51972, -1.34301
# Polymorph 171 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7645.72 eV
# Dipole moment(X, Y, Z, Debye):  4.83458, -0.47497,  1.42259
# Adding generation 13 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 14)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 14
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 14) ...
# Polymorph 94 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.15 eV
# Dipole moment(X, Y, Z, Debye):  9.73314, -3.14833,  1.27200
# Polymorph 164 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7628.7 eV
# Dipole moment(X, Y, Z, Debye): 11.18799, -2.16777,  0.37069
# Polymorph 165 unchanged
# Polymorph 172 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7640.47 eV
# Dipole moment(X, Y, Z, Debye):  8.35218, -2.67361,  0.05195
# Polymorph 173 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7626.53 eV
# Dipole moment(X, Y, Z, Debye):  9.45968,  0.49202,  1.92272
# Polymorph 174 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7649.89 eV
# Dipole moment(X, Y, Z, Debye):  3.93659,  0.87580,  0.49491
# Polymorph 175 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.78 eV
# Dipole moment(X, Y, Z, Debye):  9.00252,  0.57766, -1.68829
# Polymorph 176 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7640.61 eV
# Dipole moment(X, Y, Z, Debye):  6.21404, -2.13853,  0.18158
# Polymorph 177 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7627.86 eV
# Dipole moment(X, Y, Z, Debye):  4.95514, -2.03156, -1.20416
# Polymorph 178 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.68 eV
# Dipole moment(X, Y, Z, Debye):  8.00969, -3.17642,  0.03609
# Polymorph 179 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7655.16 eV
# Dipole moment(X, Y, Z, Debye):  4.80850,  0.05840, -1.25379
# Polymorph 180 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7628.28 eV
# Dipole moment(X, Y, Z, Debye):  5.67490, -1.59779, -1.59479
# Polymorph 181 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.04 eV
# Dipole moment(X, Y, Z, Debye):  4.32807, -2.14410, -0.04414
# Polymorph 182 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7616.99 eV
# Dipole moment(X, Y, Z, Debye):  2.49862, -3.22794,  1.18757
# Polymorph 183 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.53 eV
# Dipole moment(X, Y, Z, Debye):  5.74427,  0.15446, -1.02408
# Adding generation 14 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 15)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 15
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 15) ...
# Polymorph 94 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7640.23 eV
# Dipole moment(X, Y, Z, Debye):  9.68649, -3.13928,  1.24638
# Polymorph 164 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.37 eV
# Dipole moment(X, Y, Z, Debye): 10.68297, -1.75994, -0.79472
# Polymorph 165 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7640.02 eV
# Dipole moment(X, Y, Z, Debye):  9.56890, -2.88288, -0.21687
# Polymorph 184 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7662.7 eV
# Dipole moment(X, Y, Z, Debye):  4.65083,  0.19675, -1.19775
# Polymorph 185 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7630.74 eV
# Dipole moment(X, Y, Z, Debye):  4.25408, -3.07675,  0.62919
# Polymorph 186 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7624.76 eV
# Dipole moment(X, Y, Z, Debye):  0.96891, -0.98532, -0.45785
# Polymorph 187 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.39 eV
# Dipole moment(X, Y, Z, Debye):  3.10650, -0.88844, -0.33224
# Polymorph 188 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7649.62 eV
# Dipole moment(X, Y, Z, Debye):  3.15806,  1.80935,  0.28357
# Polymorph 189 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7626.05 eV
# Dipole moment(X, Y, Z, Debye):  5.15786, -1.93863,  0.53264
# Polymorph 190 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7656.45 eV
# Dipole moment(X, Y, Z, Debye):  5.46451, -1.20589, -1.00551
# Polymorph 191 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.68 eV
# Dipole moment(X, Y, Z, Debye):  8.00969, -3.17642,  0.03609
# Polymorph 192 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7613.35 eV
# Dipole moment(X, Y, Z, Debye):  5.09290, -2.11513, -0.19025
# Polymorph 193 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.7 eV
# Dipole moment(X, Y, Z, Debye):  4.04152, -3.75718, -0.81483
# Polymorph 194 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7630.46 eV
# Dipole moment(X, Y, Z, Debye):  6.27077,  1.23353,  1.36006
# Polymorph 195 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7651.21 eV
# Dipole moment(X, Y, Z, Debye):  2.16195, -1.15579, -1.11283
# Adding generation 15 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 16)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 16
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 16) ...
# Polymorph 94 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.96 eV
# Dipole moment(X, Y, Z, Debye):  9.74654, -3.66364,  1.82871
# Polymorph 164 unchanged
# Polymorph 165 unchanged
# Polymorph 196 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7648.92 eV
# Dipole moment(X, Y, Z, Debye):  6.00852,  3.69802, -1.47250
# Polymorph 197 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7625.87 eV
# ...
# Polymorph 304 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.01 eV
# Dipole moment(X, Y, Z, Debye):  5.63621, -0.80757, -2.38937
# Polymorph 305 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.1 eV
# Dipole moment(X, Y, Z, Debye): 11.99041, -2.43564, -0.21638
# Polymorph 306 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.5 eV
# Dipole moment(X, Y, Z, Debye): 10.91117, -1.45363, -0.89260
# Polymorph 307 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.89 eV
# Dipole moment(X, Y, Z, Debye): 11.44269, -2.38978,  1.60507
# Polymorph 308 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.85 eV
# Dipole moment(X, Y, Z, Debye):  5.61772,  0.34392, -2.62958
# Polymorph 309 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7658.87 eV
# Dipole moment(X, Y, Z, Debye):  5.20554, -0.18909, -1.27761
# Polymorph 310 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7629.88 eV
# Dipole moment(X, Y, Z, Debye): 11.56862, -0.41922, -0.40387
# Polymorph 311 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.8 eV
# Dipole moment(X, Y, Z, Debye):  9.53137,  0.21889, -0.99419
# Polymorph 312 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7654.87 eV
# Dipole moment(X, Y, Z, Debye):  9.26142, -2.25278, -1.02736
# Polymorph 313 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7629.55 eV
# Dipole moment(X, Y, Z, Debye): 10.13136, -1.54414,  0.79483
# Polymorph 314 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.61 eV
# Dipole moment(X, Y, Z, Debye):  8.66229, -0.44589,  0.18877
# Polymorph 315 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7652.17 eV
# Dipole moment(X, Y, Z, Debye):  8.04854, -2.29045, -1.96611
# Adding generation 25 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 26)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 26
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 26) ...
# Polymorph 250 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.52 eV
# Dipole moment(X, Y, Z, Debye): 10.46708, -3.79400,  0.80856
# Polymorph 280 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.19 eV
# Dipole moment(X, Y, Z, Debye): 13.35583, -2.85141,  0.20142
# Polymorph 300 unchanged
# Polymorph 316 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.45 eV
# Dipole moment(X, Y, Z, Debye):  8.46857,  2.25769, -1.21376
# Polymorph 317 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7632.02 eV
# Dipole moment(X, Y, Z, Debye): 10.42598,  0.02863,  0.46782
# Polymorph 318 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7657.57 eV
# Dipole moment(X, Y, Z, Debye):  8.05481, -3.49650, -0.39690
# Polymorph 319 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.57 eV
# Dipole moment(X, Y, Z, Debye):  6.19114, -1.42825, -0.87343
# Polymorph 320 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.23 eV
# Dipole moment(X, Y, Z, Debye): 12.27732, -3.06295, -0.71766
# Polymorph 321 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7659.14 eV
# Dipole moment(X, Y, Z, Debye):  5.31327, -2.26738, -2.76491
# Polymorph 322 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.23 eV
# Dipole moment(X, Y, Z, Debye):  6.75498, -1.10534, -0.91047
# Polymorph 323 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.87 eV
# Dipole moment(X, Y, Z, Debye): 10.29929, -1.42517,  0.37076
# Polymorph 324 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.38 eV
# Dipole moment(X, Y, Z, Debye): 10.22473,  0.12264, -1.02980
# Polymorph 325 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7645.64 eV
# Dipole moment(X, Y, Z, Debye):  9.65001, -4.69163, -0.74850
# Polymorph 326 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7651.74 eV
# Dipole moment(X, Y, Z, Debye):  4.01511, -0.01376, -1.93674
# Polymorph 327 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7632.6 eV
# Dipole moment(X, Y, Z, Debye): 13.77790, -2.51103,  0.98102
# Adding generation 26 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 27)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 27
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 27) ...
# Polymorph 280 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.2 eV
# Dipole moment(X, Y, Z, Debye): 13.42567, -2.55431,  0.82529
# Polymorph 300 unchanged
# Polymorph 327 unchanged
# Polymorph 328 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.9 eV
# Dipole moment(X, Y, Z, Debye):  9.91273, -3.31519, -1.36070
# Polymorph 329 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7657.15 eV
# Dipole moment(X, Y, Z, Debye):  8.03000, -2.89534,  0.22027
# Polymorph 330 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7653.58 eV
# Dipole moment(X, Y, Z, Debye):  6.76330, -0.80406, -1.32906
# Polymorph 331 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.03 eV
# Dipole moment(X, Y, Z, Debye): 10.11126, -2.16877, -0.93037
# Polymorph 332 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7659.86 eV
# Dipole moment(X, Y, Z, Debye):  6.29003, -1.15237, -1.89224
# Polymorph 333 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7636.99 eV
# Dipole moment(X, Y, Z, Debye): 11.43142, -3.29162, -0.22092
# Polymorph 334 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.43 eV
# Dipole moment(X, Y, Z, Debye): 10.70863, -1.78724, -0.26036
# Polymorph 335 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.22 eV
# Dipole moment(X, Y, Z, Debye): 10.15764,  0.03351, -1.04631
# Polymorph 336 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.7 eV
# Dipole moment(X, Y, Z, Debye): 10.75516, -1.14938,  0.36487
# Polymorph 337 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7649.97 eV
# Dipole moment(X, Y, Z, Debye):  5.07485,  0.24444, -2.82251
# Polymorph 338 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7646.62 eV
# Dipole moment(X, Y, Z, Debye):  6.80056, -0.73449, -0.23340
# Polymorph 339 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.76 eV
# Dipole moment(X, Y, Z, Debye): 11.24679, -0.85417, -2.09612
# Adding generation 27 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 28)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 28
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 28) ...
# Polymorph 280 unchanged
# Polymorph 300 unchanged
# Polymorph 327 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7633.98 eV
# Dipole moment(X, Y, Z, Debye): 13.53547, -2.42384,  0.92050
# Polymorph 340 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.18 eV
# Dipole moment(X, Y, Z, Debye): 10.05628,  0.61387, -0.61515
# Polymorph 341 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7642.27 eV
# Dipole moment(X, Y, Z, Debye): 10.29267, -2.23466, -0.49683
# Polymorph 342 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7638.07 eV
# Dipole moment(X, Y, Z, Debye): 10.16428, -1.70139,  0.00348
# Polymorph 343 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7652.56 eV
# Dipole moment(X, Y, Z, Debye):  9.02414,  1.43204, -0.86817
# Polymorph 344 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7629.97 eV
# Dipole moment(X, Y, Z, Debye): 12.34095, -4.32488,  2.70826
# Polymorph 345 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.2 eV
# Dipole moment(X, Y, Z, Debye): 10.95615, -2.74273, -1.51682
# Polymorph 346 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7644.64 eV
# Dipole moment(X, Y, Z, Debye): 11.46989, -2.64124, -1.16618
# Polymorph 347 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7658.17 eV
# Dipole moment(X, Y, Z, Debye):  4.56361, -0.72311, -2.29707
# Polymorph 348 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7631.74 eV
# Dipole moment(X, Y, Z, Debye):  9.85519, -3.49125,  0.24798
# Polymorph 349 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7645.01 eV
# Dipole moment(X, Y, Z, Debye):  2.92990,  0.64194,  0.45874
# Polymorph 350 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.96 eV
# Dipole moment(X, Y, Z, Debye):  3.28353,  0.86959, -0.89846
# Polymorph 351 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.92 eV
# Dipole moment(X, Y, Z, Debye):  9.69495,  0.38705, -1.26999
# Adding generation 28 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 29)
# Updating current_generation and current_properties
# #------------------------------------------------------------
# #  Generation 29
# #------------------------------------------------------------
# Mutating all polymorphs of current generation...
# Attempting gene crossovers ...
# Evaluating current generation (# 29) ...
# Polymorph 280 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.19 eV
# Dipole moment(X, Y, Z, Debye): 13.55309, -1.16073,  0.49414
# Polymorph 327 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.91 eV
# Dipole moment(X, Y, Z, Debye): 13.40581, -2.35209,  0.90271
# Polymorph 344 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.75 eV
# Dipole moment(X, Y, Z, Debye): 11.79514, -3.88067,  1.27840
# Polymorph 352 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7647.72 eV
# Dipole moment(X, Y, Z, Debye):  9.56805, -1.58505, -1.33997
# Polymorph 353 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.92 eV
# Dipole moment(X, Y, Z, Debye): 11.40292, -0.89394, -0.53553
# Polymorph 354 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.67 eV
# Dipole moment(X, Y, Z, Debye): 10.10432, -3.03175, -0.87791
# Polymorph 355 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.19 eV
# Dipole moment(X, Y, Z, Debye): 12.53267, -2.64378, -0.15344
# Polymorph 356 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7648.28 eV
# Dipole moment(X, Y, Z, Debye):  6.23375, -4.26571, -0.49121
# Polymorph 357 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7639.84 eV
# Dipole moment(X, Y, Z, Debye): 11.54012, -3.47151,  0.57602
# Polymorph 358 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.47 eV
# Dipole moment(X, Y, Z, Debye): 10.76954, -1.06188,  0.85552
# Polymorph 359 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7648.6 eV
# Dipole moment(X, Y, Z, Debye): 10.61719, -3.04358, -0.85923
# Polymorph 360 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7641.29 eV
# Dipole moment(X, Y, Z, Debye): 11.01324, -2.25857,  0.59558
# Polymorph 361 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.17 eV
# Dipole moment(X, Y, Z, Debye): 13.86977, -1.14692, -0.25669
# Polymorph 362 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7650.85 eV
# Dipole moment(X, Y, Z, Debye): 10.81063,  0.24142,  0.80043
# Polymorph 363 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7660.65 eV
# Dipole moment(X, Y, Z, Debye):  6.06203, -0.04831, -2.11057
# Adding generation 29 to population_timeline
# ------------------------------------------------------------
# Creating next generation (# 30)
# Updating current_generation and current_properties
# Evaluating current generation (# 30) ...
# Polymorph 280 unchanged
# Polymorph 327 unchanged
# Polymorph 361 unchanged
# Polymorph 364 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7640.03 eV
# Dipole moment(X, Y, Z, Debye): 12.15717, -0.10207,  0.68416
# Polymorph 365 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.56 eV
# Dipole moment(X, Y, Z, Debye): 14.42877, -1.49036,  0.41688
# Polymorph 366 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.23 eV
# Dipole moment(X, Y, Z, Debye): 10.38912, -2.82638, -1.09288
# Polymorph 367 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.38 eV
# Dipole moment(X, Y, Z, Debye): 11.10667,  1.29554, -0.49574
# Polymorph 368 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7655.13 eV
# Dipole moment(X, Y, Z, Debye):  6.84400, -3.14047, -1.40317
# Polymorph 369 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7643.4 eV
# Dipole moment(X, Y, Z, Debye): 10.49138,  0.59127,  1.11215
# Polymorph 370 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7635.28 eV
# Dipole moment(X, Y, Z, Debye): 11.77187, -2.52985,  1.08536
# Polymorph 371 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7648.92 eV
# Dipole moment(X, Y, Z, Debye):  7.82430, -1.32955,  0.60541
# Polymorph 372 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7637.94 eV
# Dipole moment(X, Y, Z, Debye): 12.64057, -2.96063,  0.27608
# Polymorph 373 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7634.75 eV
# Dipole moment(X, Y, Z, Debye): 11.79514, -3.88067,  1.27840
# Polymorph 374 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7651.56 eV
# Dipole moment(X, Y, Z, Debye): 10.91192, -0.63022,  0.24598
# Polymorph 375 was mutated, needs evaluation
# Starting restricted Hartree-Fock calculation ...
# E(RHF) = -7645.98 eV
# Dipole moment(X, Y, Z, Debye):  9.99023, -1.77935, -0.87642

# %%
ga.plotTimeline(Polymorph.DIPOLE_MOMENT)

# %%
ga.analyzeTimeline(yscale='linear')

# %%
best_pm = ga.findBestPolymorphOfAll()
# Out:
# Best overall polymorph: Child of 327 & 345, ID: 361 in generation 29.
# Fitness: dipole_moment = 13.919474607137875 Debye

# %%
best_pm.visualize('pybel')
# Out:
# <div id="molecule_c526dd41-4ce1-41f9-87b8-b0998d28e540"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_c526dd41-4ce1-41f9-87b8-b0998d28e540');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
#                $d.imolecule.addElements({});
#                $d.imolecule.draw({"atoms":[{"charge":-0.03092979035081531,"element":"C","location":[-0.31262232745293406,-0.2010275072840858,0.3091054146614223]},{"charge":-0.06814417567932447,"element":"C","location":[1.213901672547066,-0.2010275072840858,0.3091054146614223]},{"charge":-0.03092979035081531,"element":"C","location":[-0.4780632987561091,-0.20102750728408572,-1.21599340676959]},{"charge":0.03092979035081531,"element":"H","location":[-0.6093109431624287,-0.19518545718843766,1.3660692005401363]},{"charge":0.03092979035081531,"element":"H","location":[-0.7981751846836022,-0.8146990792813432,-0.46157768944658206]},{"charge":0.27944893399430687,"element":"C","location":[2.2667595507690015,0.22318208399896383,1.3042597029772947]},{"charge":0.022714725226441496,"element":"H","location":[0.5084388983069673,0.6275742422173117,0.18556835155610507]},{"charge":0.022714725226441496,"element":"H","location":[0.9091742769762157,-1.2092339108818497,0.6097205165393382]},{"charge":-0.34368720669481234,"element":"N","location":[-1.6902731974872924,0.5622837179854943,-0.9479161255248212]},{"element":"H","location":[-0.5215444666724461,-1.2600480789181794,-0.9349901011085546]},{"charge":0.11456240223160417,"element":"H","location":[-0.9710503981376747,0.7463076470921657,-1.4630128589738127]},{"charge":-0.27944893399430687,"element":"O","location":[3.154923981791524,0.7209904757147257,1.989562982338925]},{"charge":0.022714725226441496,"element":"H","location":[1.3750598642022391,-0.4260404819560948,1.3370334106172126]},{"charge":0.11456240223160417,"element":"H","location":[-1.4622296493479208,1.5132554874142428,-1.2369223883472071]},{"charge":0.11456240223160417,"element":"H","location":[-2.5849887788926065,0.1146958756552584,-1.1500124237212883]}],"bonds":[{"atoms":[10,8],"order":1},{"atoms":[13,8],"order":1},{"atoms":[2,4],"order":1},{"atoms":[14,8],"order":1},{"atoms":[6,1],"order":1},{"atoms":[0,3],"order":1},{"atoms":[1,7],"order":1},{"atoms":[1,12],"order":1},{"atoms":[5,11],"order":2}],"formula":"C4H9NO","molecular_weight":87.12036,"units":{"molecular_weight":"g / mol"}});
#
#                $d.resizable({
#                    aspectRatio: 400 / 300,
#                    resize: function (evt, ui) {
#                        $d.imolecule.renderer.setSize(ui.size.width,
#                                                      ui.size.height);
#                    }
#                });
#            });
#            </script>

# %%
ga.renderGeneration()

# %%
ga.doMultipleGenerationSteps(20)

# %%
ga.plotTimeline()

# %%
ga.analyzeTimeline()

# %%
ga.analyzeGeneticDiversity()

# %%
import pybel
pybel.Ipython_3d = True

# %%
best.zmat

# %%
ob_best = pybel.readstring('gzmat', best.gzmat_string)

# %%
help(pybel.readstring)

# %%
ob_best

# %%
ga.plotTimeline(Polymorph.DIPOLE_MOMENT)

# %%
ga.properties_timeline[0].sort_values(Polymorph.DIPOLE_MOMENT)

# %%
highest_dm_pm = ga.population_timeline[0][13]

# %%
pybel.readstring('gzmat', highest_dm_pm.gzmat_string)
